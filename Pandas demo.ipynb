# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public_cut.csv')

# %%
df.shape
# Out:
# (39999, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39999 entries, 0 to 39998
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              39999 non-null  int64
#  1   MainBranch              39999 non-null  object
#  2   Hobbyist                39999 non-null  object
#  3   OpenSourcer             39999 non-null  object
#  4   OpenSource              39096 non-null  object
#  5   Employment              39261 non-null  object
#  6   Country                 39999 non-null  object
#  7   Student                 39228 non-null  object
#  8   EdLevel                 38956 non-null  object
#  9   UndergradMajor          34076 non-null  object
#  10  EduOther                38003 non-null  object
#  11  OrgSize                 32361 non-null  object
#  12  DevType                 36695 non-null  object
#  13  YearsCode               39651 non-null  object
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df.head(10)
# Out:
#            Column                                       QuestionText
# 0      Respondent  Randomized respondent ID number (not in order ...
# 1      MainBranch  Which of the following options best describes ...
# 2        Hobbyist                            Do you code as a hobby?
# 3     OpenSourcer        How often do you contribute to open source?
# 4      OpenSource  How do you feel about the quality of open sour...
# 5      Employment  Which of the following best describes your cur...
# 6         Country          In which country do you currently reside?
# 7         Student  Are you currently enrolled in a formal, degree...
# 8         EdLevel  Which of the following best describes the high...
# 9  UndergradMajor  What was your main or most important field of ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 39994       40242             I am a student who is learning to code      Yes
# 39995       40243                     I am a developer by profession      Yes
# 39996       40244                     I am a developer by profession      Yes
# 39997       40245                     I am a developer by profession      Yes
# 39998       40246                     I am a developer by profession       No
#
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.iloc[0] #integer location -you can pass a list of raws and cols -ex. df.iloc[[0,1], [0]]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
df.loc[0, 'Respondent'] #here I can use labels
# Out:
# 1

# %%
df.shape
# Out:
# (39999, 85)

# %%
df['Respondent']
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 39994    40242
# 39995    40243
# 39996    40244
# 39997    40245
# 39998    40246
# Name: Respondent, Length: 39999, dtype: int64

# %%
df['Hobbyist'].value_counts() #it counts how many of all possible answers
# Out:
# Yes    32135
# No      7864
# Name: Hobbyist, dtype: int64

# %%
df.loc[0:3, 'Hobbyist':'Employment'] #it slices the raws from 0 to 3, col from 'Hobbyist' to 'Employment'
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
# 3       No                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time
# 3                      Employed full-time

# %%
df.set_index('Employment')
# Out:
#                                                     Respondent  \
# Employment
# Not employed, and not looking for work                       1
# Not employed, but looking for work                           2
# Employed full-time                                           3
# Employed full-time                                           4
# Employed full-time                                           5
# ...                                                        ...
# Employed full-time                                       40242
# Employed full-time                                       40243
# Employed full-time                                       40244
# Independent contractor, freelancer, or self-emp...       40245
# Employed full-time                                       40246
#
#                                                                                            MainBranch  \
# Employment
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                     Column                                       QuestionText
# 84              SurveyEase  How easy or difficult was this survey to compl...
# 83            SurveyLength  How do you feel about the length of the survey...
# 82              Dependents  Do you have any dependents (e.g., children, el...
# 81               Ethnicity  Which of the following do you identify as? Ple...
# 80               Sexuality  Which of the following do you currently identi...
# 79                   Trans                    Do you identify as transgender?
# 78                  Gender  Which of the following do you currently identi...
# 77                     Age  What is your age (in years)? If you prefer not...
# 76            SONewContent  Would you like to see any of the following on ...
# 75           WelcomeChange  Compared to last year, how welcome do you feel...
# 74                  SOComm  Do you consider yourself a member of the Stack...
# ...

# %%
filt = (df['Employment'] == 'Employed full-time') & (df['Country'] == 'Italy')

# %%
df.loc[filt] #negation of filter is given by: df.loc[~filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 62             63                     I am a developer by profession      Yes
# 117           118                     I am a developer by profession      Yes
# 313           315                     I am a developer by profession       No
# 345           347                     I am a developer by profession      Yes
# 368           370  I am not primarily a developer, but I write co...      Yes
# ...           ...                                                ...      ...
# 39504       39748                     I am a developer by profession       No
# 39611       39856             I am a student who is learning to code       No
# 39615       39860                     I am a developer by profession      Yes
# 39624       39869                     I am a developer by profession      Yes
# 39691       39936                     I am a developer by profession      Yes
#
# ...

# %%
female = (df['Gender'] == 'Woman') & (df['ConvertedComp'] > 70000) & (df['Country'] != 'United States')

# %%
df.loc[female, ['Country', 'ConvertedComp']]
# Out:
#               Country  ConvertedComp
# 99             Canada       229016.0
# 179         Argentina        84000.0
# 475    United Kingdom       130847.0
# 540            Canada        83972.0
# 568            France        74474.0
# ...               ...            ...
# 37401         Ireland       687444.0
# 38090  United Kingdom        80471.0
# 38644       Australia      1000000.0
# 38752         Iceland        92196.0
# 39055  United Kingdom       439644.0
#
# [183 rows x 2 columns]

# %%
countries = ('Italy', 'Canada')
filt_2 = df['Country'].isin(countries)

# %%
df.loc[filt_2]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 11             12             I am a student who is learning to code       No
# 20             21                        I code primarily as a hobby      Yes
# 30             31             I am a student who is learning to code       No
# 36             37                        I code primarily as a hobby      Yes
# ...           ...                                                ...      ...
# 39867       40114                     I am a developer by profession      Yes
# 39915       40163                     I am a developer by profession      Yes
# 39928       40176                     I am a developer by profession      Yes
# 39952       40200             I am a student who is learning to code       No
# 39991       40239                     I am a developer by profession      Yes
#
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
filt_3 = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt_3]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 1               2  I am a student who is learning to code       No
# 3               4          I am a developer by profession       No
# 4               5          I am a developer by profession      Yes
# 7               8             I code primarily as a hobby      Yes
# ...           ...                                     ...      ...
# 39986       40234  I am a student who is learning to code      Yes
# 39989       40237          I am a developer by profession       No
# 39991       40239          I am a developer by profession      Yes
# 39992       40240          I am a developer by profession      Yes
# 39996       40244          I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %%
df.rename(columns = {'Respondent': 'newlabel_0', 'MainBranch' : 'newlabel_1'})
# Out:
#        newlabel_0                                         newlabel_1 Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 39994       40242             I am a student who is learning to code      Yes
# 39995       40243                     I am a developer by profession      Yes
# 39996       40244                     I am a developer by profession      Yes
# 39997       40245                     I am a developer by profession      Yes
# 39998       40246                     I am a developer by profession       No
#
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.rename(columns = {'Respondent': 'newlabel_0', 'MainBranch' : 'newlabel_1'}, inplace=True) 
#to actually change the dataframe you need to add inplace=True

# %%
df.columns
# Out:
# Index(['newlabel_0', 'newlabel_1', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc[2]
# Out:
# newlabel_0                                                                3
# newlabel_1                I am not primarily a developer, but I write co...
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                                               Employed full-time
# Country                                                            Thailand
# Student                                                                  No
# EdLevel                            Bachelor’s degree (BA, BS, B.Eng., etc.)
# UndergradMajor                                Web development or web design
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                100 to 499 employees
# ...

# %%
# change just a value in the df
df.loc[2, 'Hobbyist'] = ['MAYBE']

# change a list of values
df.loc[2, ]

# %%
df.loc[2, ['Hobbyist', 'OpenSourcer']] = ['MAYBE', 'YOU BETTER BE']

# %%
df.loc[2]
# Out:
# newlabel_0                                                                3
# newlabel_1                I am not primarily a developer, but I write co...
# Hobbyist                                                              MAYBE
# OpenSourcer                                                   YOU BETTER BE
# OpenSource                The quality of OSS and closed source software ...
# Employment                                               Employed full-time
# Country                                                            Thailand
# Student                                                                  No
# EdLevel                            Bachelor’s degree (BA, BS, B.Eng., etc.)
# UndergradMajor                                Web development or web design
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                100 to 499 employees
# ...
